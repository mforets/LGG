# %%
Pkg.add("ODE")
# Out:
# INFO: Cloning cache of ODE from https://github.com/JuliaDiffEq/ODE.jl.git
# INFO: Cloning cache of Polynomials from https://github.com/Keno/Polynomials.jl.git
# INFO: Installing ODE v0.2.1
# INFO: Installing Polynomials v0.1.0
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of ODE
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
Pkg.update()
# Out:
# INFO: Updating METADATA...
# INFO: Updating cache of ColorTypes...
# INFO: Updating cache of Gadfly...
# INFO: Updating cache of ZMQ...
# INFO: Updating cache of DataFrames...
# INFO: Updating cache of Rmath...
# INFO: Updating cache of DataArrays...
# INFO: Updating cache of Loess...
# INFO: Updating cache of Compat...
# INFO: Updating cache of Iterators...
# INFO: Updating cache of PDMats...
# INFO: Updating cache of DataFrames...
# INFO: Computing changes...
# INFO: Upgrading ArgParse: v0.3.1 => v0.4.0
# INFO: Upgrading Blink: v0.4.2 => v0.4.3
# INFO: Upgrading ColorTypes: v0.2.11 => v0.2.12
# INFO: Upgrading Compat: v0.9.2 => v0.9.3
# INFO: Upgrading Conda: v0.3.2 => v0.4.0
# INFO: Upgrading DataArrays: v0.3.8 => v0.3.10
# INFO: Upgrading Gadfly: v0.5.1 => v0.5.2
# INFO: Upgrading Iterators: v0.1.10 => v0.2.0
# INFO: Upgrading Loess: v0.0.7 => v0.1.0
# INFO: Upgrading NaNMath: v0.2.1 => v0.2.2
# INFO: Upgrading PDMats: v0.5.0 => v0.5.1
# ...

# %%
Pkg.build("Homebrew")
# Out:
# INFO: Building Homebrew
# Already up-to-date.
# Uninstalling icu4c... (265 files, 65.0M)
# ==============================[ ERROR: Homebrew ]===============================
#
# LoadError: SystemError: opening file /Users/forets/.julia/v0.5/Homebrew/deps/usr/Library/Taps/staticfloat/homebrew-juliatranslated/icu4c.rb: No such file or directory
# while loading /Users/forets/.julia/v0.5/Homebrew/deps/build.jl, in expression starting on line 2
#
# ...
#
# ================================[ BUILD ERRORS ]================================
#
# WARNING: Homebrew had build errors.
#
#  - packages with build errors remain installed in /Users/forets/.julia/v0.5
#  - build the package(s) and all dependencies with `Pkg.build("Homebrew")`
#  - build a single package by running its `deps/build.jl` script
#
# ...

# %%
using ODE;
# Out:
# INFO: Precompiling module Polynomials.
# WARNING: Module Compat with uuid 78808661067658 is missing from the cache.
# This may mean module Compat does not support precompilation but is imported by a module that does.
# ERROR: LoadError: Declaring __precompile__(false) is not allowed in files that are being precompiled.
#  in require(::Symbol) at ./loading.jl:385
#  in require(::Symbol) at /Applications/Julia-0.5.app/Contents/Resources/julia/lib/julia/sys.dylib:?
#  in include_from_node1(::String) at ./loading.jl:488
#  in include_from_node1(::String) at /Applications/Julia-0.5.app/Contents/Resources/julia/lib/julia/sys.dylib:?
#  in macro expansion; at ./none:2 [inlined]
#  in anonymous at ./<missing>:?
#  in eval(::Module, ::Any) at ./boot.jl:234
#  in eval(::Module, ::Any) at /Applications/Julia-0.5.app/Contents/Resources/julia/lib/julia/sys.dylib:?
#  in process_options(::Base.JLOptions) at ./client.jl:239
#  in _start() at ./client.jl:318
# ...
