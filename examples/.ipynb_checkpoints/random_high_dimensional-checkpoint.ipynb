# %% [markdown]
# Purposes:
#
# * for benchmarking with high dimensional polytopes

# %% [markdown]
# a note: it works pretty well with the config:
#
# ```python
# # order of the system
# n = 3
# A = random_matrix(RDF, n, n)
# %%time
# fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=QQ, solver='Gurobi')
# # plot the result
# plot_flowpipe(fp)
# ```

# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

# %%
# order of the system
n = 6
A = random_matrix(RDF, n, n)

# %%
# time horizon 
T = 1

# initial condition 
X0 = BoxInfty(center = random_vector(n), radius = 0.1)

# time discretization 
tau = 1e-2

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=RDF, solver='Gurobi')
# Out:
# CPU times: user 6.07 s, sys: 742 ms, total: 6.81 s
# Wall time: 8.73 s

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# WARNING: projection directions not specified. Assuming directions=[0,1]
# /Applications/SageMath/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Graphics object consisting of 8100 graphics primitives
