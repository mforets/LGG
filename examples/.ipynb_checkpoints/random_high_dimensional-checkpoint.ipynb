# %% [markdown]
# Purposes:
#
# * for benchmarking with high dimensional polytopes

# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

# %%
# order of the system
n = 5
A = random_matrix(RDF, n, n)

# %%
# time horizon 
T = 10

# initial condition 
X0 = BoxInfty(center = zero_vector(n), radius = 0.1)

# time discretization 
tau = 1e-1

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=QQ, solver='Gurobi')
# Out:
# CPU times: user 1min 28s, sys: 1.22 s, total: 1min 29s
# Wall time: 1min 29s

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# WARNING: projection directions not specified. Assuming directions=[0,1]
# Graphics object consisting of 4192 graphics primitives
