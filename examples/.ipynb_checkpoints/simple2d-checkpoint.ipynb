# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

A = matrix([[-1, -4], [4, -1]])

B = identity_matrix(2)

# time horizon 
T = 1

# input domain U
mu = 0.05
U = BoxInfty(center = [0,0], radius = mu)

# initial condition 
X0 = BoxInfty(center = [1,0], radius = 0.1)

# time discretization 
tau = 1e-3

# %%
# %%time
fp = compute_flowpipe(A, X0, B, U, time_horizon = T, time_step = tau, directions={'select':'oct'},solver='Gurobi',base_ring=RDF)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-9bac1d584556> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"fp = compute_flowpipe(A, X0, B, U, time_horizon = T, time_step = tau, directions={'select':'oct'},soler='Gurobi',base_ring=RDF)")
#
# /Applications/SageMath/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Applications/SageMath/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
# ...

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 999 graphics primitives
