# %% [markdown]
# Purposes:
#
# * for benchmarking with high dimensional polytopes

# %% [markdown]
# a note: it works pretty well with the config:
#
# ```python
# # order of the system
# n = 3
# A = random_matrix(RDF, n, n)
# %%time
# fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=QQ, solver='Gurobi')
# # plot the result
# plot_flowpipe(fp)
# ```

# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

# %%
# order of the system
n = 6
A = random_matrix(RDF, n, n)

# %%
# time horizon 
T = 1

# initial condition 
X0 = BoxInfty(center = random_vector(n), radius = 0.1)

# time discretization 
tau = 1e-3

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=QQ, solver='Gurobi')
# Out:
# ---------------------------------------------------------------------------
# MIPSolverException                        Traceback (most recent call last)
# <ipython-input-34-89e22688a885> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau, base_ring=QQ, solver='Gurobi')")
#
# /Applications/SageMath/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2101             magic_arg_s = self.var_expand(line, stack_depth)
#    2102             with self.builtin_trap:
# -> 2103                 result = fn(magic_arg_s, cell)
#    2104             return result
#    2105
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Applications/SageMath/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Applications/SageMath/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1174         else:
#    1175             st = clock2()
# -> 1176             exec(code, glob, local_ns)
#    1177             end = clock2()
#    1178             out = None
#
# <timed exec> in <module>()
#
# /Users/forets/SAGE/LGG/src/lgg.pyc in compute_flowpipe(A, X0, B, U, **kwargs)
#     240     for i in range(len(dArray)):
#     241         d = dArray[i]
# --> 242         Omega_i_Family_SF.append( _Omega_i_supports(d) )
#     243
#     244     # ################################################
#
# /Users/forets/SAGE/LGG/src/lgg.pyc in _Omega_i_supports(d)
#     278     r.append(d)
#     279     s.append(_sage_const_0 )
# --> 280     rhoi.append(supp_fun_polyhedron(Omega0, d, solver=solver, verbose=verbose))
#     281
#     282     for i in (ellipsis_range(_sage_const_0 ,Ellipsis,N-_sage_const_2 )):
#
# /Users/forets/SAGE/LGG/lib/polyFunctions_core.pyc in supp_fun_polyhedron(P, d, verbose, return_xopt, solver)
#     634         s_LP.show()
#     635
# --> 636     oval = s_LP.solve()
#     637     xopt = s_LP.get_values(x);
#     638
#
# /Applications/SageMath/src/sage/numerical/mip.pyx in sage.numerical.mip.MixedIntegerLinearProgram.solve (/Applications/SageMath/src/build/cythonized/sage/numerical/mip.c:15223)()
#    2241         """
#    2242         if log is not None: self._backend.set_verbosity(log)
# -> 2243         self._backend.solve()
#    2244         return self._backend.get_objective_value()
#    2245
#
# /Applications/SageMath/src/sage/numerical/backends/gurobi_backend.pyx in sage.numerical.backends.gurobi_backend.GurobiBackend.solve (/Applications/SageMath/src/build/cythonized/sage/numerical/backends/gurobi_backend.c:6809)()
#     711         # Has there been a problem ?
#     712         if status[0] != GRB_OPTIMAL:
# --> 713             raise MIPSolverException("Gurobi: "+mip_status.get(status[0], "unknown error during call to GRBoptimize : "+str(status[0])))
#     714
#     715
#
# MIPSolverException: Gurobi: The problem is infeasible or unbounded

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# WARNING: projection directions not specified. Assuming directions=[0,1]
# Graphics object consisting of 19000 graphics primitives
