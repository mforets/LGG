# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

A = matrix([[-1, -4], [4, -1]])

B = identity_matrix(2)

# time horizon 
T = 1.5

# input domain U
mu = 0.000000001
U = BoxInfty(center = [0,0], radius = mu)

# initial condition 
X0 = BoxInfty(center = [1,0], radius = 0.1)

# time discretization 
tau = 1e-2

# %%
# %%time
fp = compute_flowpipe(A, X0, B, U, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 898 ms, sys: 65.2 ms, total: 963 ms
# Wall time: 827 ms

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 900 graphics primitives

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 580 ms, sys: 45.5 ms, total: 625 ms
# Wall time: 503 ms

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 900 graphics primitives
