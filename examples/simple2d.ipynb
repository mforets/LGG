# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

A = matrix([[-1, -4], [4, -1]])

B = identity_matrix(2)

# time horizon 
T = 1

# input domain U
mu = 0.1
U = BoxInfty(center = [0,0], radius = mu)

# initial condition 
X0 = BoxInfty(center = [1,0], radius = 0.1)

# time discretization 
tau = 1e-2

# %%
# %%time
fp = compute_flowpipe(A, X0, B, U, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 1.11 s, sys: 50.4 ms, total: 1.16 s
# Wall time: 1.04 s

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# /Applications/SageMath/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Graphics object consisting of 600 graphics primitives

# %% [markdown]
# ## Homogeneous case

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 770 ms, sys: 77.6 ms, total: 847 ms
# Wall time: 685 ms

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 600 graphics primitives
