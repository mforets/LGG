# %%
import sys
sys.path.append('..')

from src.lgg import compute_flowpipe, plot_flowpipe
from lib.polyFunctions_core import BoxInfty

A = matrix([[-1, -4], [4, -1]])

B = identity_matrix(2)

# time horizon 
T = 1

# input domain U
mu = 0.1
U = BoxInfty(center = [0,0], radius = mu)

# initial condition 
X0 = BoxInfty(center = [1,0], radius = 0.1)

# time discretization 
tau = 1e-2

# %%
# %%time
fp = compute_flowpipe(A, X0, B, U, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 618 ms, sys: 61.4 ms, total: 680 ms
# Wall time: 551 ms

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 600 graphics primitives

# %% [markdown]
# ## Homogeneous case

# %%
# %%time
fp = compute_flowpipe(A, X0, time_horizon = T, time_step = tau)
# Out:
# CPU times: user 448 ms, sys: 56.6 ms, total: 505 ms
# Wall time: 380 ms

# %%
# plot the result
plot_flowpipe(fp)
# Out:
# Graphics object consisting of 600 graphics primitives
